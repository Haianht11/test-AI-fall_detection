# %% [markdown]
# <a href="https://colab.research.google.com/github/Haianht11/test-AI-fall_detection/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Haianht11/test-AI-fall_detection.git
# Out:
# Cloning into 'test-AI-fall_detection'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 0), reused 14 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), done.

# %%
# !unzip -q "/content/drive/MyDrive/archive (1).zip" -d "/content/test-AI-fall_detection/data"
# Out:
# replace /content/test-AI-fall_detection/data/Fall/Keypoints_CSV/20240912_101331_keypoints.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %cd /content/test-AI-fall_detection

# Thêm file, commit và push
# !git add .
# !git commit -m "Update project files"
# !git push origin main

print("✅ Push thành công!")
# Out:
# /content/test-AI-fall_detection
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ Push thành công!

# %%
# !python train.py
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory
